# %%
import sklearn

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
digit = datasets.load_digits()
bc=datasets.load_breast_cancer()

# %%
print "features: {}".format(digit['data'][:10])
print "target: {}".format(digit['target'][:10])
# Out:
# features: [[  0.   0.   5.  13.   9.   1.   0.   0.   0.   0.  13.  15.  10.  15.
#     5.   0.   0.   3.  15.   2.   0.  11.   8.   0.   0.   4.  12.   0.
#     0.   8.   8.   0.   0.   5.   8.   0.   0.   9.   8.   0.   0.   4.
#    11.   0.   1.  12.   7.   0.   0.   2.  14.   5.  10.  12.   0.   0.
#     0.   0.   6.  13.  10.   0.   0.   0.]
#  [  0.   0.   0.  12.  13.   5.   0.   0.   0.   0.   0.  11.  16.   9.
#     0.   0.   0.   0.   3.  15.  16.   6.   0.   0.   0.   7.  15.  16.
#    16.   2.   0.   0.   0.   0.   1.  16.  16.   3.   0.   0.   0.   0.
#     1.  16.  16.   6.   0.   0.   0.   0.   1.  16.  16.   6.   0.   0.
#     0.   0.   0.  11.  16.  10.   0.   0.]
#  [  0.   0.   0.   4.  15.  12.   0.   0.   0.   0.   3.  16.  15.  14.
#     0.   0.   0.   0.   8.  13.   8.  16.   0.   0.   0.   0.   1.   6.
#    15.  11.   0.   0.   0.   1.   8.  13.  15.   1.   0.   0.   0.   9.
#    16.  16.   5.   0.   0.   0.   0.   3.  13.  16.  16.  11.   5.   0.
# ...

# %%
print "features: {}".format(bc['data'][:10])
print "target: {}".format(bc['target'][:10])
# Out:
# features: [[  1.79900000e+01   1.03800000e+01   1.22800000e+02   1.00100000e+03
#     1.18400000e-01   2.77600000e-01   3.00100000e-01   1.47100000e-01
#     2.41900000e-01   7.87100000e-02   1.09500000e+00   9.05300000e-01
#     8.58900000e+00   1.53400000e+02   6.39900000e-03   4.90400000e-02
#     5.37300000e-02   1.58700000e-02   3.00300000e-02   6.19300000e-03
#     2.53800000e+01   1.73300000e+01   1.84600000e+02   2.01900000e+03
#     1.62200000e-01   6.65600000e-01   7.11900000e-01   2.65400000e-01
#     4.60100000e-01   1.18900000e-01]
#  [  2.05700000e+01   1.77700000e+01   1.32900000e+02   1.32600000e+03
#     8.47400000e-02   7.86400000e-02   8.69000000e-02   7.01700000e-02
#     1.81200000e-01   5.66700000e-02   5.43500000e-01   7.33900000e-01
#     3.39800000e+00   7.40800000e+01   5.22500000e-03   1.30800000e-02
#     1.86000000e-02   1.34000000e-02   1.38900000e-02   3.53200000e-03
#     2.49900000e+01   2.34100000e+01   1.58800000e+02   1.95600000e+03
# ...

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB

gnb=GaussianNB
bnb=BernoulliNB
mnb=MultinomialNB
digit1=cross_val_score(gnb,digit)
digit2=model_selection.cross_val_score(bnb,digit)
digit3=model_selection.cross_val_score(mnb,digit)

digit1.mean()
digit2.mean()
digit3.mean()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-60-fb9d7954c5ba> in <module>()
#       6 bnb=BernoulliNB
#       7 mnb=MultinomialNB
# ----> 8 digit1=cross_val_score(gnb,digit)
#       9 digit2=sklearn.model_selection.cross_val_score(bnb,digit)
#      10 digit3=sklearn.model_selection.cross_val_score(mnb,digit)
#
# NameError: name 'cross_val_score' is not defined

# %%
bc1=model_selection.cross_val_score(gnb,bc)
bc2=model_selection.cross_val_score(bnb,bc)
bc3=model_selection.cross_val_score(mnb,bc)
bc1.mean()
bc2.mean()
bc3.mean()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-4f2f6526c90d> in <module>()
# ----> 1 bc1=sklearn.model_selection.cross_val_score(gnb,bc)
#       2 bc2=sklearn.model_selection.cross_val_score(bnb,bc)
#       3 bc3=sklearn.model_selection.cross_val_score(mnb,bc)
#       4 bc1.mean()
#       5 bc2.mean()
#
# NameError: name 'sklearn' is not defined

# %% [markdown]
# В этом месте я не смог запустить функцию cross_val_score и сделать выводы о показателях эффективности наивных байесовских классификаторов разных распределений. В связи с этим остальные задания, для выполнения которых необходимо знать значения, возвращаемые функцией mean(), тоже не сделаны. Извините.
